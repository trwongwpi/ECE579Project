# %%
# !unzip /content/drive/MyDrive/pytorch-YOLOv4.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: pytorch-YOLOv4/data/roboflow/train/868125667_jpg.rf.8fd8879cb772e583d72d3589cd45a680.jpg
#   inflating: pytorch-YOLOv4/data/roboflow/train/868125667_jpg.rf.b14361e0a3091c6f3a2b8a138fcf49cf.jpg
#   inflating: pytorch-YOLOv4/data/roboflow/train/868363241_jpg.rf.27a1e1d03b68051a6f0b0a8d7e1925e1.jpg
#   inflating: pytorch-YOLOv4/data/roboflow/train/868363241_jpg.rf.6516117ee6cff102cad40d3b16f57647.jpg
#   inflating: pytorch-YOLOv4/data/roboflow/train/868363241_jpg.rf.71c056dfcff9863e11f91c3ad1f12973.jpg
#   inflating: pytorch-YOLOv4/data/roboflow/train/868534569_jpg.rf.d065ba7c7e14105ca3e0f8023c72dda0.jpg
#   inflating: pytorch-YOLOv4/data/roboflow/train/868534569_jpg.rf.dbfdc5635796f5fd76c0abf1fc199f80.jpg
#   inflating: pytorch-YOLOv4/data/roboflow/train/868534569_jpg.rf.fa7d02f0a5bea95308d5d54c957dcb8f.jpg
#   inflating: pytorch-YOLOv4/data/roboflow/train/868650194_jpg.rf.4ca5e6fda162914b1e69e7199e2cd8b1.jpg
# ...

# %%
# !pip install tensorboardx
# !pip install fast_pytorch_kmeans
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !python /content/pytorch-YOLOv4/sparse.py
# Out:
# evaluating...
# in function convert_to_coco_api...
# creating index...
# index created!
# Accumulating evaluation results...
# DONE (t=36.58s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.242
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.644
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.486
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.486
# ...

# %%
# !python /content/pytorch-YOLOv4/models.py 52 /content/drive/MyDrive/Yolov4_epoch1.pth /content/pytorch-YOLOv4/data/roboflow/test/004843130_jpg.rf.70d99d0334e006679aa00a74d4ea745b.jpg 608 608 /content/pytorch-YOLOv4/data/roboflow/test/_classes.txt
# Out:
# Sparse model has size=24.58 MiB
# -----------------------------------
#            Preprocess : 0.001569
#       Model Inference : 0.545331
# -----------------------------------
# -----------------------------------
#        max and argmax : 0.005397
#                   nms : 0.000880
# Post processing total : 0.006277
# -----------------------------------
# -----------------------------------
#            Preprocess : 0.000344
#       Model Inference : 0.458262
# -----------------------------------
# -----------------------------------
#        max and argmax : 0.005180
#                   nms : 0.000799
# Post processing total : 0.005979
# -----------------------------------
# 4H: 0.993676
# (206, 157)
# (310, 139)
# 6D: 0.998784
# (267, 171)
# (370, 153)
# 6D: 0.972403
# (253, 178)
# (356, 160)
# QD: 0.999722
# (331, 219)
# (407, 201)
# QD: 0.999710
# (361, 489)
# (437, 471)
# QD: 0.999513
# (375, 481)
# (451, 463)
# QD: 0.999199
# (345, 211)
# (449, 193)
# ...

# %%
# !python /content/pytorch-YOLOv4/train.py -f /content/pytorch-YOLOv4/Yolov4_epoch10.pth -dir /content/pytorch-YOLOv4/data/roboflow/train -classes 52 -g 0
# Out:
# Traceback (most recent call last):
#   File "/content/pytorch-YOLOv4/train.py", line 33, in <module>
#     from models import Yolov4
#   File "/content/pytorch-YOLOv4/models.py", line 6, in <module>
#     from sparse import get_model_size
#   File "/content/pytorch-YOLOv4/sparse.py", line 5, in <module>
#     from models import Yolov4
# ImportError: cannot import name 'Yolov4' from partially initialized module 'models' (most likely due to a circular import) (/content/pytorch-YOLOv4/models.py)
