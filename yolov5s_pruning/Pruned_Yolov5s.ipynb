# %%
# !git clone https://github.com/uyzhang/yolov5_prune.git
# Out:
# Cloning into 'yolov5_prune'...
# remote: Enumerating objects: 191, done.
# remote: Counting objects: 100% (191/191), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 191 (delta 79), reused 149 (delta 46), pack-reused 0
# Receiving objects: 100% (191/191), 845.87 KiB | 25.63 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
# %cd /content/yolov5_prune
#after following the link above, recieve python code with these fields filled in
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="RZvD73Ob16lp3QyzuD6G")
project = rf.workspace("augmented-startups").project("playing-cards-ow27d")
dataset = project.version(4).download("yolov5")
# Out:
# /content/yolov5_prune
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 39.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
# !python train.py --batch 64 --epochs 60 --weights /content/drive/MyDrive/best_v5.pt --data /content/drive/MyDrive/data.yaml --cfg /content/yolov5_prune/models/yolov5s.yaml --name coco_sparsity --optimizer AdamW --bn_sparsity --sparsity_rate 0.00005 --device 0
# Out:
# ...
# 2023-12-01 18:29:13.758993: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 18:29:13.759047: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 18:29:13.759080: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-01 18:29:14.954761: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python prune.py --percent 0.50 --weights runs/train/coco_sparsity/weights/best.pt --data /content/drive/MyDrive/data.yaml --cfg /content/yolov5_prune/models/yolov5s.yaml  --imgsz 640
# Out:
# prune: data=/content/drive/MyDrive/data.yaml, weights=['runs/train/coco_sparsity/weights/best.pt'], cfg=/content/yolov5_prune/models/yolov5s.yaml, percent=0.5, batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, val_in_prune=False
# YOLOv5 🚀 ckp-1-g8d2a4ad torch 2.1.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Suggested Gamma threshold should be less than 0.5771484375
# The corresponding prune ratio is 0.7677801724137931, but you can set higher
# Gamma value that less than 0.355712890625 are set to zero
# ...
# |	layer name               |         origin channels     |         remaining channels  |
# |	model.0.bn               |         32                  |         27                  |
# ...

# %%
# !python val.py --data /content/drive/MyDrive/data.yaml --weights /content/drive/MyDrive/best_v5.pt
# Out:
# ...
# val: data=/content/drive/MyDrive/data.yaml, weights=['/content/drive/MyDrive/best_v5.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 ckp-1-g8d2a4ad torch 2.1.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# Model Summary: 232 layers, 7384065 parameters, 0 gradients
# val: Scanning 'Playing-Cards-4/valid/labels' images and labels...2020 found, 0 missing, 0 empty, 0 corrupted: 100% 2020/2020 [00:00<00:00, 8399.98it/s]
# val: New cache created: Playing-Cards-4/valid/labels.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 64/64 [00:18<00:00,  3.52it/s]
#                  all       2020       8080      0.998      0.999      0.995      0.718
# ...

# %%
# !python train.py --img 640 --batch 32 --epochs 10 --weights /content/yolov5_prune/runs/val/exp5/pruned_model.pt  --data /content/drive/MyDrive/data.yaml --cfg /content/yolov5_prune/models/yolov5s.yaml  --name coco_ft --device 0 --optimizer AdamW --ft_pruned_model --hyp /content/yolov5_prune/data/hyps/hyp.finetune_prune.yaml
# Out:
# 2023-12-01 19:26:17.604269: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 19:26:17.604315: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 19:26:17.604345: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-01 19:26:18.850827: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# %cp /content/yolov5_prune/runs/val/exp/Best_pruned_model.pt /content/gdrive/My\ Drive
# Out:
# cp: cannot stat '/content/yolov5_prune/runs/val/exp/pruned_model.pt': No such file or directory

# %%
# !python detect.py --weights /content/yolov5_prune/runs/train/coco_ft3/weights/fuck.pt --source
